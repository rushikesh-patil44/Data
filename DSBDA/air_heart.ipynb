# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random as rd

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
ds = pd.read_csv("airquality_data.csv", encoding="ISO-8859-1")
# Out:
# C:\Users\Rushikesh Idhate\AppData\Local\Temp\ipykernel_5336\208299440.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   ds = pd.read_csv("airquality_data.csv", encoding="ISO-8859-1")

# %%
ds
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
ds.head()
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5        date
# 0                         NaN    NaN  1990-02-01
# 1                         NaN    NaN  1990-02-01
# 2                         NaN    NaN  1990-02-01
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     291665 non-null  object
#  1   sampling_date                435739 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435739 non-null  object
#  4   agency                       286261 non-null  object
#  5   type                         430349 non-null  object
#  6   so2                          401096 non-null  float64
#  7   no2                          419509 non-null  float64
#  8   rspm                         395520 non-null  float64
#  9   spm                          198355 non-null  float64
#  10  location_monitoring_station  408251 non-null  object
#  11  pm2_5                        9314 non-null    float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
ds.isnull().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
ds.dropna()
# Out:
# Empty DataFrame
# Columns: [stn_code, sampling_date, state, location, agency, type, so2, no2, rspm, spm, location_monitoring_station, pm2_5, date]
# Index: []

# %%
df.dropna()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
ds1=ds.loc[111:999, ['state', 'location', 'so2', 'rspm']]
ds2=ds.loc[[1,3,5,2,4,22,43,54,67,7,8,9,50,10,11]]

# %%
ds1
# Out:
#               state        location   so2  rspm
# 111  Andhra Pradesh       Hyderabad   4.9   NaN
# 112  Andhra Pradesh  Vishakhapatnam   NaN   NaN
# 113  Andhra Pradesh  Vishakhapatnam  11.2   NaN
# 114  Andhra Pradesh  Vishakhapatnam   4.5   NaN
# 115  Andhra Pradesh       Hyderabad   6.2   NaN
# ..              ...             ...   ...   ...
# 995  Andhra Pradesh       Hyderabad   2.8   NaN
# 996  Andhra Pradesh       Hyderabad   5.0   NaN
# 997  Andhra Pradesh       Hyderabad   5.5   NaN
# 998  Andhra Pradesh       Hyderabad   5.8   NaN
# 999  Andhra Pradesh       Hyderabad   5.9   NaN
#
# [889 rows x 4 columns]

# %%
ds2
# Out:
#    stn_code        sampling_date           state   location  \
# 1     151.0   February - M021990  Andhra Pradesh  Hyderabad
# 3     150.0      March - M031990  Andhra Pradesh  Hyderabad
# 5     152.0      March - M031990  Andhra Pradesh  Hyderabad
# 2     152.0   February - M021990  Andhra Pradesh  Hyderabad
# 4     151.0      March - M031990  Andhra Pradesh  Hyderabad
# 22    152.0  September - M091990  Andhra Pradesh  Hyderabad
# 43    152.0        May - M051991  Andhra Pradesh  Hyderabad
# 54    151.0  September - M091991  Andhra Pradesh  Hyderabad
# 67    203.0    January - M011992  Andhra Pradesh  Hyderabad
# 7     151.0      April - M041990  Andhra Pradesh  Hyderabad
# 8     152.0      April - M041990  Andhra Pradesh  Hyderabad
# 9     151.0        May - M051990  Andhra Pradesh  Hyderabad
# 50    150.0     August - M081991  Andhra Pradesh  Hyderabad
# 10    152.0        May - M051990  Andhra Pradesh  Hyderabad
# 11    150.0       June - M061990  Andhra Pradesh  Hyderabad
#
# ...

# %%
ds_integration=pd.concat([ds1,ds2])
ds_integration
# Out:
#               state        location   so2  rspm stn_code     sampling_date  \
# 111  Andhra Pradesh       Hyderabad   4.9   NaN      NaN               NaN
# 112  Andhra Pradesh  Vishakhapatnam   NaN   NaN      NaN               NaN
# 113  Andhra Pradesh  Vishakhapatnam  11.2   NaN      NaN               NaN
# 114  Andhra Pradesh  Vishakhapatnam   4.5   NaN      NaN               NaN
# 115  Andhra Pradesh       Hyderabad   6.2   NaN      NaN               NaN
# ..              ...             ...   ...   ...      ...               ...
# 8    Andhra Pradesh       Hyderabad   4.2   NaN    152.0   April - M041990
# 9    Andhra Pradesh       Hyderabad   4.0   NaN    151.0     May - M051990
# 50   Andhra Pradesh       Hyderabad   8.5   NaN    150.0  August - M081991
# 10   Andhra Pradesh       Hyderabad   3.6   NaN    152.0     May - M051990
# 11   Andhra Pradesh       Hyderabad   3.9   NaN    150.0    June - M061990
#
#     agency                                type   no2    spm  \
# ...

# %%
ds_integration.transpose()
# Out:
#                                         111             112             113  \
# state                        Andhra Pradesh  Andhra Pradesh  Andhra Pradesh
# location                          Hyderabad  Vishakhapatnam  Vishakhapatnam
# so2                                     4.9             NaN            11.2
# rspm                                    NaN             NaN             NaN
# stn_code                                NaN             NaN             NaN
# sampling_date                           NaN             NaN             NaN
# agency                                  NaN             NaN             NaN
# type                                    NaN             NaN             NaN
# no2                                     NaN             NaN             NaN
# spm                                     NaN             NaN             NaN
# location_monitoring_station             NaN             NaN             NaN
# ...

# %%
ds.drop(columns="so2")
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
ds2.drop(3)
# Out:
#    stn_code        sampling_date           state   location  \
# 1     151.0   February - M021990  Andhra Pradesh  Hyderabad
# 5     152.0      March - M031990  Andhra Pradesh  Hyderabad
# 2     152.0   February - M021990  Andhra Pradesh  Hyderabad
# 4     151.0      March - M031990  Andhra Pradesh  Hyderabad
# 22    152.0  September - M091990  Andhra Pradesh  Hyderabad
# 43    152.0        May - M051991  Andhra Pradesh  Hyderabad
# 54    151.0  September - M091991  Andhra Pradesh  Hyderabad
# 67    203.0    January - M011992  Andhra Pradesh  Hyderabad
# 7     151.0      April - M041990  Andhra Pradesh  Hyderabad
# 8     152.0      April - M041990  Andhra Pradesh  Hyderabad
# 9     151.0        May - M051990  Andhra Pradesh  Hyderabad
# 50    150.0     August - M081991  Andhra Pradesh  Hyderabad
# 10    152.0        May - M051990  Andhra Pradesh  Hyderabad
# 11    150.0       June - M061990  Andhra Pradesh  Hyderabad
#
#                                      agency  \
# ...

# %%
ds.melt()
# Out:
#          variable       value
# 0        stn_code       150.0
# 1        stn_code       151.0
# 2        stn_code       152.0
# 3        stn_code       150.0
# 4        stn_code       151.0
# ...           ...         ...
# 5664641      date  2015-12-24
# 5664642      date  2015-12-29
# 5664643      date         NaN
# 5664644      date         NaN
# 5664645      date         NaN
#
# [5664646 rows x 2 columns]

# %%
ds_merged=pd.concat([ds,df])
ds_merged
# Out:
#     stn_code       sampling_date           state   location agency  \
# 0      150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1      151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2      152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3      150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4      151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# ..       ...                 ...             ...        ...    ...
# 298      NaN                 NaN             NaN        NaN    NaN
# 299      NaN                 NaN             NaN        NaN    NaN
# 300      NaN                 NaN             NaN        NaN    NaN
# 301      NaN                 NaN             NaN        NaN    NaN
# 302      NaN                 NaN             NaN        NaN    NaN
#
#                                    type  so2   no2  rspm  spm  ...   chol  \
# 0    Residential, Rural and other Areas  4.8  17.4   NaN  NaN  ...    NaN
# ...

# %%
from sklearn import linear_model, metrics

# %%
X=df[["age"]]
Y=df[["thall"]]

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.2, random_state=1)

# %%
len(X_train)
# Out:
# 242

# %%
len(X_test)
# Out:
# 61

# %%
ds.shape
# Out:
# (435742, 13)

# %%
reg=linear_model.LinearRegression()
print(X_train)
# Out:
#      age
# 62    52
# 127   67
# 111   57
# 287   57
# 108   50
# ..   ...
# 203   68
# 255   45
# 72    29
# 235   51
# 37    54
#
# [242 rows x 1 columns]

# %%
model=reg.fit(X_train, Y_train)

# %%
r_sq=reg.score(X_train, Y_train)
r_sq
# Out:
# 0.005160903314535115

# %% [markdown]
# print(model.intercept_)

# %% [raw]
# print(model.coef_)
